# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset, and it was downloaded using web scraping techniques. The data contains registers from **Fotocasa** which is one of the most popular real estate websites in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and in no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# This CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')
max_index_price = ds["price"].idxmax()
data = ds.loc[max_index_price]
print(f"The house with address {data['address']} is the most expensive and its price is {data['price']} USD")
# Out:
# The house with address El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is the cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
min_price_index = ds["price"].idxmin()
data = ds.loc[min_price_index]
print(f"The house with address {data['address']} is the cheapest and its price is {data['price']} USD")
# Out:
# The house with address Parla is the cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The biggest house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smallest house is located on County Road 1 N and its surface is 200 meters`

# %%
import pandas as pd

SURFACE_COLUMN = "surface"
data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
max_surface_index = data_frame[SURFACE_COLUMN].idxmax()
min_surface_index = data_frame[SURFACE_COLUMN].idxmin()
max_surface_data = data_frame.loc[max_surface_index]
min_surface_data = data_frame.loc[min_surface_index]

print(f"The biggest house is located on {max_surface_data['address']} and its surface is {max_surface_data['surface']} meters")
print(f"The smallest house is located on {min_surface_data['address']} and its surface is {min_surface_data['surface']} meters")
# Out:
# The biggest house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smallest house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the names of the populations with a comma as a separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
import pandas as pd

LEVEL_FIVE = "level5"

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
populations = data_frame[LEVEL_FIVE].unique()
print(*populations, sep=", ")
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`True` or `False`) followed by the rows/cols that contains NAs.

# %%
import pandas as pd

print(pd.read_csv('assets/real_estate.csv', sep=';').isna())
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions.

# %%
import pandas as pd

original_data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
edited_data_frame = original_data_frame.dropna()
print(f"Original dimensions: {original_data_frame.shape}")
print(f"Edited dimensions (without NAs): {edited_data_frame.shape}")
# Out:
# Original dimensions: (15335, 37)
# Edited dimensions (without NAs): (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value.

# %%
import pandas as pd

LEVEL_FIVE = "level5"

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
data = data_frame.loc[data_frame[LEVEL_FIVE] == "Arroyomolinos (Madrid)"]
print(data["price"].dropna().mean())
# Out:
# 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

LEVEL_FIVE = "level5"

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
data = data_frame.loc[data_frame[LEVEL_FIVE] == "Arroyomolinos (Madrid)"]

plt.figure(figsize = (10, 5))
plt.hist(data["price"].dropna(), bins=20, edgecolor = "black", alpha=0.7)
plt.title("Histogram of Prices in Arroyomolinos (Madrid)")
plt.xlabel("Price (in USD)")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# The histogram of property prices in Arroyomolinos (Madrid) reveals a notable distribution. More than half of the properties are clustered in a price range between 1,500,000 and 3,800,000 USD, with frequencies exceeding 7.5, and some even reaching or surpassing 20. This indicates a significant concentration of properties within that price range, suggesting that the market in this area has a considerable number of high-value homes.
#
# On the other hand, prices outside this range show very low frequencies, with most properties not exceeding a frequency of 2.5. This suggests that there are few options for more affordable properties in the area, which may indicate a real estate market focused on luxury or high-value homes.
#
# In summary, the analysis of the histogram indicates that Arroyomolinos (Madrid) is a locality where high-priced properties prevail, which could influence market accessibility for potential buyers.

# %% [markdown]
# #### Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about them.

# %%
import pandas as pd

LEVEL_FIVE = "level5"

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')

valdemorillo_data = data_frame.loc[data_frame[LEVEL_FIVE] == "Valdemorillo"]
galapagar_data = data_frame.loc[data_frame[LEVEL_FIVE] == "Galapagar"]

valdemorillo_price_mean = valdemorillo_data["price"].dropna().mean()
galapagar_price_mean = galapagar_data["price"].dropna().mean()

print(f"Average price in Valdemorillo: {valdemorillo_price_mean:.2f} USD")
print(f"Average price in Galapagar: {galapagar_price_mean:.2f} USD")

if valdemorillo_price_mean == galapagar_price_mean:
    conclusion = "The average prices of Valdemorillo and Galapagar are the same."
else:
    conclusion = "The average prices of Valdemorillo and Galapagar are different."

print(conclusion)
# Out:
# Average price in Valdemorillo: 363860.29 USD
# Average price in Galapagar: 360063.20 USD
# The average prices of Valdemorillo and Galapagar are different.

# %% [markdown]
# #### Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
import pandas as pd

LEVEL_FIVE = "level5"

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
data_frame["pps"] = data_frame["price"] / data_frame["surface"]

valdemorillo_data = data_frame.loc[data_frame[LEVEL_FIVE] == "Valdemorillo"]
galapagar_data = data_frame.loc[data_frame[LEVEL_FIVE] == "Galapagar"]


valdemorillo_pps_mean = valdemorillo_data["pps"].dropna().mean()
galapagar_pps_mean = galapagar_data["pps"].dropna().mean()

print(f"Average price in Valdemorillo: {valdemorillo_pps_mean:.2f} USD")
print(f"Average price in Galapagar: {galapagar_pps_mean:.2f} USD")

if valdemorillo_pps_mean == galapagar_pps_mean:
    conclusion = "The average price per square meter of Valdemorillo and Galapagar are the same."
else:
    conclusion = "The average price per square meter of Valdemorillo and Galapagar are different."
    
print(conclusion)
# Out:
# Average price in Valdemorillo: 1317.95 USD
# Average price in Galapagar: 1606.32 USD
# The average price per square meter of Valdemorillo and Galapagar are different.

# %% [markdown]
# #### Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot`, then write a conclusion about it.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')

surface = data_frame["surface"]
price = data_frame["price"]

plt.figure(figsize = (10, 5))
plt.scatter(surface, price, color="blue", alpha=0.5)
plt.title("Relation between Surface and Price of Houses")
plt.xlabel("Surface (m²)")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# The plot shows a positive linear relationship between surface area and price of properties. As surface area increases, the price generally rises proportionally. Most points follow this linear trend, suggesting that in this dataset, property prices are heavily influenced by their size in square meters.

# %% [markdown]
# #### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
#
# Print the obtained value.

# %%
import pandas as pd

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
print(data_frame["realEstate_name"].dropna().nunique())
# Out:
# 1821

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses.

# %%
import pandas as pd
LEVEL_FIVE = "level5"
data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
population = data_frame[LEVEL_FIVE].value_counts()
print(f"The population {population.idxmax()} has {population.max()} houses.")
# Out:
# The population  Madrid Capital has 6643 houses.

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`.

# %%
import pandas as pd

LEVEL_FIVE = "level5"
data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
print(south_belt_df)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

LEVEL_FIVE = "level5"
data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

plt.figure(figsize = (10, 5))
plt.bar(south_belt_df[LEVEL_FIVE], south_belt_df["price"].median())
plt.title("Median of the prices")
plt.show()

# %% [markdown]
# The bar plot shows the median housing prices across four populations in the south belt of Madrid: Fuenlabrada, Leganés, Getafe, and Alcorcón. The data reveals that the median prices are quite similar across these cities, with each reaching values around 175,000 USD. This consistency may indicate a balanced real estate market in these areas, where factors affecting housing prices are relatively uniform among them.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in Exercise 14) (★★★)
#
# Print both values for each variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt
LEVEL_FIVE = "level5"
data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]

print(f"Mean price value:{south_belt_df['price'].mean()}")
print(f"Variance price value:{south_belt_df['price'].var()}")
print(f"Mean rooms value: {south_belt_df['rooms'].mean()}")
print(f"Variance rooms value: {south_belt_df['rooms'].var()}")
print(f"Mean surface value: {south_belt_df['surface'].mean()}")
print(f"Variance surface value: {south_belt_df['surface'].var()}")
print(f"Mean bathrooms value:{south_belt_df['bathrooms'].mean()}")
print(f"Variance bathrooms value:{south_belt_df['bathrooms'].var()}")
# Out:
# Mean price value:223094.48070562293
# Variance price value:14921367508.04902
# Mean rooms value: 3.0177383592017737
# Variance rooms value: 0.7188858892927542
# Mean surface value: 111.75222363405337
# Variance surface value: 4263.051760316337
# Mean bathrooms value:1.633221850613155
# Variance bathrooms value:0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house in each population? You must use the subset obtained in Exercise 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population.

# %%
import pandas as pd
import matplotlib.pyplot as plt
LEVEL_FIVE = "level5"
data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
exp_house_index = south_belt_df['price'].idxmax()

most_expensive_houses = south_belt_df.loc[south_belt_df.groupby(LEVEL_FIVE)['price'].idxmax()]

for _, row in most_expensive_houses.iterrows():
    print(f"The most expensive house in {row[LEVEL_FIVE]} is at {row['address']} for {row['price']} USD")
# Out:
# The most expensive house in Alcorcón is at Alcorcón for 950000 USD
# The most expensive house in Fuenlabrada is at Calle de Paulo Freire, 5, Fuenlabrada for 490000 USD
# The most expensive house in Getafe is at Getafe for 1050000 USD
# The most expensive house in Leganés is at Avenida Reina Sofía, Leganés for 650000 USD

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in Exercise 14) (★★★)
#
# For the normalization method, you can use the one you consider; there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot.
#
# Hint: You can help yourself by reviewing the *multihist* demo of Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt

LEVEL_FIVE = "level5"
N_BINS = 10

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])].copy()

south_belt_df['normalized_price'] = south_belt_df.groupby(LEVEL_FIVE)['price'].transform(lambda x: x / x.max())

fig, axes = plt.subplots(1, 4, figsize=(20, 6), sharey=True)

colors = ["purple", "blue", "green", "orange"]
populations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

for i, population in enumerate(populations):
    subset = south_belt_df[south_belt_df[LEVEL_FIVE] == population]
    axes[i].hist(subset['normalized_price'].dropna(), bins=N_BINS, color=colors[i], alpha=0.7)
    axes[i].set_title(population)
    axes[i].set_xlabel("Normalized Price")

axes[0].set_ylabel("Frequency")
fig.suptitle("Normalized Price Distribution by Population")
plt.show()

# %% [markdown]
# Analysis of Normalized Price Histograms
#
# The histograms of the populations Fuenlabrada, Leganés, Getafe, and Alcorcón reveal similar patterns in the distribution of normalized prices, with some notable differences:
#
# Price Distribution in Each Population:
#
# • Fuenlabrada: The histogram shows its highest peak between the ranges of 0.2 and 0.4, indicating that most properties fall within this relative price range. The remaining values are spread more uniformly, with less concentration in higher prices.
# • Leganés: Here, the highest peak is around the 0.2 range, suggesting that a large number of properties are clustered at the lower end of the normalized price range. The other values are distributed evenly across the remaining ranges, with no additional concentrations in higher prices.
# • Getafe: This histogram has two notable peaks, one in the 0.0 range and another at 0.4, with the latter being the highest. This suggests that Getafe has a wider price distribution, with some properties in the low range and others closer to the maximum relative price.
# • Alcorcón: In this population, the highest peak is just below 0.2, indicating a tendency toward relatively lower prices. The remaining prices are spread out evenly across the rest of the range, with no significant concentrations in higher values.
#
#
# • Comparison Between Populations:
#     ◇ Overall, the histograms show that all four populations have prices mostly concentrated within the lower ranges of the normalized scale, meaning there is a predominance of lower-priced properties in each area.
#     ◇ Getafe is the only population showing a slight tendency toward higher prices, as reflected by its second peak at 0.4.
#     ◇ This suggests that while the four populations share a similar price range, Getafe may have a slightly higher proportion of properties at higher relative prices.
#
#
# The histograms confirm that prices in the four populations are within a similar range, with a slight difference in Getafe, which has somewhat higher prices compared to the others.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
import pandas as pd
import matplotlib.pyplot as plt

LEVEL_FIVE = "level5"
N_BINS = 10

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])].copy()
south_belt_df = south_belt_df[south_belt_df['surface'] > 0]
south_belt_df["pps"] = south_belt_df['price'] / south_belt_df['surface']

fig, axes = plt.subplots(1, 2, figsize = (16, 4), sharey = True)
 
colors = ["purple", "green"]
populations = ["Getafe", "Alcorcón"]
for i, population in enumerate(populations):
    subset = south_belt_df[south_belt_df[LEVEL_FIVE] == population]
    axes[i].hist(subset['pps'].dropna(), bins=N_BINS, color = colors[i], alpha = 0.7)
    axes[i].set_title(population)
    axes[i].set_xlabel("Price per square meter (EUR/m²)")

axes[0].set_ylabel("Frequency")
fig.suptitle("Price per square meter (EUR/m²) between Getafe and Alcorcón")
plt.show()

# %% [markdown]
# • Getafe: Tends to have a higher concentration of properties at a relatively affordable price per square meter, centered between 1500 and 2000 EUR/m².
# • Alcorcón: Shows more dispersed and slightly higher prices in some cases, though at lower frequencies, particularly in the 2000 to 2500 EUR/m² range.
#
# In Getafe, the properties tend to be more affordable on average than in Alcorcón, where price per square meter is more spread out and peaks at somewhat higher values. This suggests that in Getafe, there are more options at moderate prices, while in Alcorcón, prices can reach higher ranges, though less frequently.

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph. You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Make a scatter plot of each population using subplots.

# %%
import pandas as pd
import matplotlib.pyplot as plt

LEVEL_FIVE = "level5"

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])].copy()
south_belt_df = south_belt_df[south_belt_df['surface'] > 0]
south_belt_df["pps"] = south_belt_df['price'] / south_belt_df['surface']

fig, axes = plt.subplots(1, 4, figsize = (20, 5), sharey = True)
 
colors = ["purple", "green", "yellow", "blue"]
populations = [ "Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
for i, population in enumerate(populations):
    subset = south_belt_df.loc[south_belt_df[LEVEL_FIVE] == population]
    axes[i].scatter(subset['surface'], subset['pps'], label = population, color = colors[i])
    axes[i].set_title(population)
    axes[i].set_xlabel("Surface (m²)")


axes[0].set_ylabel("Price per square meter (EUR/m²)")
fig.suptitle("Price per square meter (EUR/m²)  for Different Populations")
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centered on (60 degrees latitude and -2.2 degrees longitude)
# Latitude, longitude
map = Map(center=(60, -2.2), zoom=2, min_zoom=1, max_zoom=20, basemap=basemaps.Esri.WorldTopoMap)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
import pandas as pd
from ipyleaflet import Marker, LayerGroup, AwesomeIcon
## HERE: plot the coordinates of the estates
LEVEL_FIVE = "level5"
POPULATIONS = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
COLORS = ['pink','red','orange', 'green']

data_frame = pd.read_csv('assets/real_estate.csv', sep=';')
south_belt_df = data_frame.loc[data_frame[LEVEL_FIVE].isin(POPULATIONS)].copy()

layer_group = LayerGroup()
color_map = dict(zip(POPULATIONS, COLORS))

for _, row in south_belt_df.iterrows():
    population = row[LEVEL_FIVE]
    icon = AwesomeIcon(
    name = row['realEstate_name'],
    marker_color = color_map.get(population, "blue"),
    icon_color='black',
    spin=False)
    latitude = float(row['latitude'].replace(',', '.'))
    longitude = float(row['longitude'].replace(',', '.'))
    marker = Marker(location=(latitude, longitude), draggable=False, icon=icon)
    layer_group.add_layer(marker)

map.add_layer(layer_group)
